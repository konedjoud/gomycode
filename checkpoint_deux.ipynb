# %%
	#EXO 1
nom = input("enter your first_name: ")
prenom = input("enter your last_name: ")
print(prenom,nom )

# %%
#EXO 2 
x = 5 
xx = str(x) + str(x)
xxx = str(x) + str(x) + str(x)
print(int(x) + int(xx) + int(xxx))

# %%
#EXO 3
#user will enter a number
test = int(input('enter a number please!:'))
if (test % 2) == 0:
    print(test, 'this number is odd')
else:
    print(test, 'this number is even')
print(test)

# %%
#EXO 4
#enter a value between 2000,3200
for test in range(2000,3201):
    if test %5!=0 and test %7 ==0:
        print(test)
print (test)

# %%
#EXO 5
num = 1
echo = int(input("enter a value"))
for i in range (1,echo+1):
    num = num*i
print ("le factorielle est:",num)

# %%
#EXO 6
test = input("entre une value: ")
test3 = len(test)
output = ""
for i in range (test3):
    if (i%2 ==0):
        output = output + test[i]
print (output)

# %%
#EXO 7
USER_PRIX= int(input("entre la valeur"))
if USER_PRIX >= 500:
    USER_PRIX = USER_PRIX -  USER_PRIX*0.5
    print("le prix est:", USER_PRIX)
elif USER_PRIX in range(200,500):
    USER_PRIX= USER_PRIX - USER_PRIX *0.3
    print("le prix est:", USER_PRIX)
elif USER_PRIX <200:
    USER_PRIX = USER_PRIX - USER_PRIX *0.1
    print("le prix est:", USER_PRIX)
print(USER_PRIX)
